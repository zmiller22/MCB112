# %%
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import os
import scipy.stats as stats
from scipy.special import logsumexp
import seaborn as sns

# %% [markdown]
# __talk about beginners game__ We are after the posterior probability $P(\mu|\vec{x},\sigma)$. Using Baye's rule, we can rewrite this as $\frac{P(\vec{x}|\mu,\sigma)P(\mu|\sigma)}{P(\vec{x}|\sigma)}$. Because $\mu$ and $\sigma$ are independent, we can drop some of the conditioning and re-write this as $\frac{P(\vec{x}|\mu,\sigma)P(\mu)}{P(\vec{x}|\sigma)}$. Lastly, we can solve for $P(\vec{x}|\sigma)$ using the law of total probability which gives $\frac{P(\vec{x}|\mu,\sigma)P(\mu)}{\sum_{\mu}P(\vec{x}|\mu,\sigma)P(\mu)} = \frac{P(\vec{x}|\mu,\sigma)}{\sum_{\mu}P(\vec{x}|\mu,\sigma)}$ (the $P(\mu)$ terms cancel since $\mu$ has a uniform probability and can thus be pulled out of the sum in the denominator).

# %%
def get_samples(n):
    """Runs the student-game.py program for the number of samples given by n and returns the mean and
    standard deviation of the distribution, as well as a list of the sampled values"""
    command = "./student-game.py " + str(n)
    r = os.popen(command) 
    output = r.readlines() 
    
    sigma = 0
    mu = 0
    samples = []
    
    for line_num, line in enumerate(output): 
        line = line.strip('\r\n')
        if line_num == 8:
            line = line.split(" ");
            mu = float(line[4].strip(","))
            sigma = float(line[-1])
        elif 11 <= line_num <= 11+(n-1):
            samples.append(float(line.strip()))
            
    return mu, sigma, samples

def get_beginner_post_probs(x_vec, sigma, mu_vec):
    """Calculates the posterior probability of mu given x_vec and sigma for each of the mu values given in 
    mu_vec"""
    prob_list = []
    for mu in mu_arr:
        prob_list.append(sum([stats.norm.logpdf(x,mu,sigma) for x in x_vec]))
    
    prob_sum = logsumexp(prob_list)
    post_probs_list = np.exp([prob-prob_sum for prob in prob_list])
    
    best_mu_prob = max(post_probs_list)
    best_mu = mu_vec[list(post_probs_list).index(best_mu_prob)]
    
    return best_mu, best_mu_prob, post_probs_list
            
def get_beginner_pub_probs(x_vec, sigma, mu_vec):
    """Given a vector of sample values, sigma, and a vector of mu values, calculates the pub's given
    probability for each value of mu in mu_vec"""
    sample_mean = np.mean(x_vec)
    n = len(x_vec)
    prob_vec = [stats.norm.logpdf(mu, sample_mean, sigma/np.sqrt(n)) for mu in mu_vec]
    total_prob = logsumexp(prob_vec)
    pub_probs_list = np.exp([prob-total_prob for prob in prob_vec])
    
    return pub_probs_list

def play_beginners_game(N, n, mu_vec):
    true_mu_list = []
    true_sigma_list = []
    samples_list = []
    post_probs_list = []
    pub_probs_list = []
    
    for iteration in range(N):
        true_mu, true_sigma, samples = get_samples(n)
        true_mu_list.append(true_mu)
        true_sigma_list.append(true_sigma)
        samples_list.append(samples)
        
        vals = get_beginner_post_probs(samples, true_sigma, mu_vec)
        post_probs_list.append(vals[2])
        
        vals = get_beginner_pub_probs(samples, true_sigma, mu_vec)
        pub_probs_list.append(vals)
        
    
    #TODO add a horizontal line for the true s.d. if there is time
    fig, axs = plt.subplots(N, figsize=(7,4*N))
    if N != 1:
        for plt_idx, ax in enumerate(axs):
            ax.semilogy(mu_vec, post_probs_list[plt_idx], color="r", alpha=0.5)
            ax.semilogy(mu_vec, pub_probs_list[plt_idx], color="b", alpha=0.5)
            ax.axvline(x=true_mu_list[plt_idx],color="k", linestyle="dashed")
            ax.label_outer()
            
        fig.suptitle("Probability Estimate Curves for $P(\mu|\sigma,x)$\n(multiple games)")
        fig.legend(["Bayesian","Pub","True $\mu$"],loc="lower right") 
        fig.text(0.5, 0.04, "$\mu$", ha="center", fontsize=12)
        fig.text(0.02, 0.5, "$P(\mu|\sigma,x)$", va="center", ha="right", rotation="vertical", fontsize=12)
    # This is an edge case for when N = 1, in which case the axs object is not iterable
    elif N == 1:
        axs.semilogy(mu_vec, post_probs_list[0], color="r", alpha=0.5)
        axs.semilogy(mu_vec, pub_probs_list[0], color="b", alpha=0.5)
        axs.axvline(x=true_mu_list[0],color="k", linestyle="dashed")
        axs.label_outer()
        
        fig.subplots_adjust(top=0.8, bottom=0.27)
        fig.suptitle("Probability Estimate Curves for $P(\mu|\sigma,x)$\n(multiple games)")
        fig.legend(["Bayesian","Pub","True $\mu$"],loc="lower right") 
        fig.text(0.5, 0.04, "$\mu$", ha="center", fontsize=12)
        fig.text(0.02, 0.5, "$P(\mu|\sigma,x)$", va="center", ha="right", rotation="vertical", fontsize=12)
        
    return samples_list, true_mu_list, true_sigma_list

# %%
#TODO check divide by zero warning message
mu_arr = np.arange(-100,110,10)
sigma_arr = np.arange(5,105,5)
vals = play_beginners_game(1,4,mu_arr)

# %%
def get_advanced_post_probs(x_vec, mu_vec, sigma_vec):
    """Get the posterior probabilities of the advanced game, also get the probabilities marginalized over 
    all values of sigma"""
    post_prob_arr = np.ones((len(sigma_vec), len(mu_vec)))
    
    # Get all the numerator probabilities
    for r_idx in range(len(sigma_vec)):
        for c_idx in range(len(mu_vec)):
            numer = sum([stats.norm.logpdf(x,mu_vec[c_idx],sigma_vec[r_idx]) for x in x_vec])
            post_prob_arr[r_idx, c_idx] = numer
            
    # Get the normalizing constant (denominator)
    denom = logsumexp(post_prob_arr)
    
    # Get the normalized posterior probabilities (subtract since we are in log)
    post_prob_arr = post_prob_arr-denom
    
    # Mariginalize over all the values of sigma
    marg_post_prob_arr = logsumexp(post_prob_arr, axis=0)
    
    post_prob_arr = np.exp(post_prob_arr)
    marg_post_prob_arr = np.exp(marg_post_prob_arr)
    
    
    return post_prob_arr, marg_post_prob_arr

def get_advanced_pub_probs(x_vec, mu_vec):
    """Given a vector of sample values, sigma, and a vector of mu values, calculates the pub's given
    probability for each value of mu in mu_vec"""
    sample_mean = np.mean(x_vec)
    s = np.std(x_vec, ddof=1)
    n = len(x_vec)
    prob_vec = [stats.norm.logpdf(mu, sample_mean, s/np.sqrt(n)) for mu in mu_vec]
    total_prob = logsumexp(prob_vec)
    pub_probs_list = np.exp([prob-total_prob for prob in prob_vec])
    
    return pub_probs_list

def t_prob_dist(X, mu_values):
    """Copied from the problem set, but changed to work with log-probabilities. Given a data vector X and 
    a list of mu values, calculates the t-distribution along all of the mu values."""
    N    = len(X)
    xbar = np.mean(X)
    s    = np.std(X, ddof=1)
    t    = [ (xbar - mu) / (s / np.sqrt(N)) for mu in mu_values ]    # t statistic, given sample mean, sample stddev, and N
#   t    = [ stats.ttest_1samp(X, mu)[0] for mu in mu_values ]       # ... (equivalently, python can calculate t statistic for you)
    Pr   = [ stats.t.logpdf(val, N-1) for val in t ]
    Z    = logsumexp(Pr)
    Pr   = [ p - Z for p in Pr ]    
    return np.exp(Pr)

def play_advanced_game(N, n, mu_vec, sigma_vec):
    """Given a number of iterations N, a sample size n, and two vectors containing the values of mu and 
    sigma, calcuates the probabilities of mu using the Bayesian approach, the pubs approach, and a
    t-distribution. Also calcuates the posterior-probability of all (mu,sigma) pairs using a Bayesian approach.
    For each iteration, plots a heatmap of the (mu,sigma) pairs, and also plots the probability lines for all
    three approaches."""
    
    true_mu_list = []
    true_sigma_list = []
    samples_list = []
    post_probs_list = []
    marg_post_probs_list = []
    pub_probs_list = []
    t_probs_list = []
    
    for iteration in range(N):
        true_mu, true_sigma, samples = get_samples(n)
        true_mu_list.append(true_mu)
        true_sigma_list.append(true_sigma)
        samples_list.append(samples)
        
        vals = get_advanced_post_probs(samples, mu_vec, sigma_vec)
        post_probs_list.append(vals[0])
        marg_post_probs_list.append(vals[1])
        
        vals = get_advanced_pub_probs(samples, mu_vec)
        pub_probs_list.append(vals)
        
        vals = t_prob_dist(samples, mu_vec)
        t_probs_list.append(vals)
        
    fig, axs = plt.subplots(N, 2, figsize=(9,3*N), sharex="col")
    if N != 1:
        for plt_idx in range(N):
            im = axs[plt_idx,0].imshow(post_probs_list[plt_idx], extent=[-100, 100, 5, 100])
            axs[plt_idx,1].semilogy(mu_vec, marg_post_probs_list[plt_idx], color="r", alpha=0.5)
            axs[plt_idx,1].semilogy(mu_vec, pub_probs_list[plt_idx], color="b", alpha=0.5)
            axs[plt_idx,1].semilogy(mu_vec, t_probs_list[plt_idx], color="g", alpha=0.5)
            axs[plt_idx,1].axvline(x=true_mu_list[plt_idx],color="k", linestyle="dashed")
            axs[plt_idx,1].yaxis.tick_right()
            axs[plt_idx,0].label_outer()
            
        # Label the plot and add legends
        # Prevents legend collision when there is only 2 rows
        if(N == 2): fig.subplots_adjust(top=0.9, bottom=0.15)
        fig.suptitle("Probability Heatmap of $P(\mu,\sigma|x)$ (left) and Probability Estimate Curves for $P(\mu|\vec{x})$ (right) \n(multiple games)")
        fig.legend(["Bayesian","Pub","T-Dist","True $\mu$"], loc="lower right") 
        cbar_ax = fig.add_axes([0.18, 0.08, 0.22, 0.01])
        fig.colorbar(im, cax=cbar_ax, orientation="horizontal")
        fig.text(0.5, 0.04, "$\mu$", ha="center", fontsize=12)
        fig.text(0.04, 0.5, "$\sigma$", rotation="vertical", fontsize=12)
        fig.text(1, 0.5, "$P(\mu|x)$", rotation=-90, fontsize=12)
    # This is an edge case for when N = 1, in which case the axs object is not iterable
    elif N == 1:
        im = axs[0].imshow(post_probs_list[0], extent=[-100, 100, 5, 100])
        axs[1].semilogy(mu_vec, marg_post_probs_list[0], color="r", alpha=0.5)
        axs[1].semilogy(mu_vec, pub_probs_list[0], color="b", alpha=0.5)
        axs[1].semilogy(mu_vec, t_probs_list[0], color="g", alpha=0.5)
        axs[1].axvline(x=true_mu_list[plt_idx],color="k", linestyle="dashed")
        axs[1].yaxis.tick_right()
        axs[0].label_outer()
    
        # Label the plot and add legends
        fig.subplots_adjust(top=0.8, bottom=0.2)
        fig.suptitle("Probability Heatmap of $P(\mu,\sigma|x)$ (left) and Probability Estimate Curves for $P(\mu|x)$ (right) \n(multiple games)")
        fig.legend(["Bayesian","Pub","T-Dist","True $\mu$"], loc="lower right") 
        cbar_ax = fig.add_axes([0.2, 0.08, 0.2, 0.05])
        fig.colorbar(im, cax=cbar_ax, orientation="horizontal")
        fig.text(0.5, 0, "$\mu$", ha="center", fontsize=12)
        fig.text(0.04, 0.5, "$\sigma$", rotation="vertical", fontsize=12)
        fig.text(1, 0.5, "$P(\mu|x)$", rotation=-90, fontsize=12)
        
    return samples_list, true_mu_list, true_sigma_list

#TODO make the plot for the specific pset values
def plot_pset_vals_advanced()

# %%
vals = play_advanced_game(4,3,mu_arr,sigma_arr)

# %%
test = np.array([[1,2,3],[4,5,6]])
print(logsumexp(test))
print(test.shape)
# Out:
# 6.456193316018123
# (2, 3)
